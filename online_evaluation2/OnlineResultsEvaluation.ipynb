# %% [markdown]
# # Phase 1 evaluation

# %%
import pandas as pd
import numpy as np
dfTesting = pd.read_csv("users_1-50/validTestingResults_UMAP2020.csv", sep=";", header=0, index_col=None)
dfTesting.head()
# Out:
#         id   userID  objectID  visited_objects             eventType  \
# 0  2042520  3341731      7094                1  object_shown_in_list
# 1  2042521  3341731      7106                1  object_shown_in_list
# 2  2042522  3341731      4108                1  object_shown_in_list
# 3  2042523  3341731      6526                1  object_shown_in_list
# 4  2042524  3341731      2331                1  object_shown_in_list
#
#    eventValue    position                 date
# 0           1  recomended  2020-01-15 23:01:57
# 1           1  recomended  2020-01-15 23:01:57
# 2           1  recomended  2020-01-15 23:01:57
# 3           1  recomended  2020-01-15 23:01:57
# 4           1  recomended  2020-01-15 23:01:57

# %%
dfIF = pd.read_csv("recent_implicit_feedback_UMAP2020_online.csv", sep=";", header=0, index_col=None)
dfIF.head()
# Out:
#         id   userID  objectID eventType  eventValue         lastModified
# 0  1322155   715904      2067  pageview          23  2020-01-27 13:18:01
# 1  1336358   883157      3126  pageview         157  2020-01-30 08:55:07
# 2  1444051  1326034       109  pageview          11  2020-02-02 20:29:50
# 3  1823559  1529905      2067  pageview         123  2020-01-27 10:42:00
# 4  1855943  1529905      2331  pageview         168  2020-01-27 10:26:31

# %%
resOO = pd.read_csv("users_1-50/results_open_UMAP2020.csv", sep=";", header=0, index_col=0)
resOO
# Out:
#             cnt
# recVariant
# 0           152
# 1           109
# 2           152
# 3           109
# 4           100
# 5            91

# %%
sum(resOO.cnt)
# Out:
# 713

# %%
resOOU = pd.read_csv("users_1-50/results_openUsers_UMAP2020.csv", sep=";", header=0, index_col=0)
resOOU
# Out:
#             cnt
# recVariant
# 0            84
# 1            68
# 2            86
# 3            63
# 4            67
# 5            56

# %%
resSO = pd.read_csv("users_1-50/results_shown_UMAP2020.csv", sep=";", header=0, index_col=0)
resSO
# Out:
#               cnt
# recVariant
# 0           21948
# 1           16910
# 2           19841
# 3           17093
# 4           19588
# 5           18682

# %%
sum(resSO.cnt)
# Out:
# 114062

# %%
resSOU = pd.read_csv("users_1-50/results_shownUsers_UMAP2020.csv", sep=";", header=0, index_col=0)
resOO["users"] = resSOU.cnt
resSOU
# Out:
#             cnt
# recVariant
# 0           664
# 1           628
# 2           668
# 3           637
# 4           655
# 5           646

# %%
resOO["clicks"] = resOO.cnt
resOO["shown"] = resSO.cnt
resOO.cnt / resSO.cnt
# Out:
# recVariant
# 0    0.006925
# 1    0.006446
# 2    0.007661
# 3    0.006377
# 4    0.005105
# 5    0.004871
# Name: cnt, dtype: float64

# %%
resOO["user_conversion"] = resOOU.cnt / resSOU.cnt
resOOU.cnt / resSOU.cnt
# Out:
# recVariant
# 0    0.126506
# 1    0.108280
# 2    0.128743
# 3    0.098901
# 4    0.102290
# 5    0.086687
# Name: cnt, dtype: float64

# %%
merged = pd.merge(dfTesting, dfIF, how='inner', on=("userID", "objectID"))
#merged.head()

# %%
import datetime
merged["dateX"] = pd.to_datetime(merged.date)
merged["lastModifiedX"] = pd.to_datetime(merged.lastModified)
merged["dtDiff"] = (merged["lastModifiedX"] - merged["dateX"]).dt.seconds
merged.head()
# Out:
#       id_x   userID  objectID  visited_objects           eventType_x  \
# 0  2042622  3341736       108                1  object_shown_in_list
# 1  2042628  3341736       108                2  object_shown_in_list
# 2  2042624  3341736       109                1  object_shown_in_list
# 3  2042630  3341736       109                2  object_shown_in_list
# 4  2042634  3341664      7115                6  object_shown_in_list
#
#    eventValue_x    position                 date     id_y eventType_y  \
# 0             1  recomended  2020-01-15 23:08:36  4402427    pageview
# 1             1  recomended  2020-01-15 23:09:12  4402427    pageview
# 2             1  recomended  2020-01-15 23:08:36  4402430    pageview
# 3             1  recomended  2020-01-15 23:09:12  4402430    pageview
# 4             1  recomended  2020-01-15 23:14:36  4402306    pageview
#
#    eventValue_y         lastModified               dateX       lastModifiedX  \
# 0             1  2020-01-15 23:07:41 2020-01-15 23:08:36 2020-01-15 23:07:41
# 1             1  2020-01-15 23:07:41 2020-01-15 23:09:12 2020-01-15 23:07:41
# 2             1  2020-01-15 23:09:12 2020-01-15 23:08:36 2020-01-15 23:09:12
# 3             1  2020-01-15 23:09:12 2020-01-15 23:09:12 2020-01-15 23:09:12
# 4             2  2020-01-15 23:21:25 2020-01-15 23:14:36 2020-01-15 23:21:25
#
#    dtDiff
# 0   86345
# 1   86309
# 2      36
# 3       0
# 4     409

# %%
mergedRestr = merged.loc[(merged.dateX < merged.lastModifiedX) & (merged.dtDiff > 5) & (merged.eventType_x == "object_shown_in_list") & (merged.visited_objects > 0) & (merged.eventType_y == "pageview")]
mergedRestr.head()
# Out:
#       id_x   userID  objectID  visited_objects           eventType_x  \
# 2  2042624  3341736       109                1  object_shown_in_list
# 4  2042634  3341664      7115                6  object_shown_in_list
# 5  2042640  3341664      7115                6  object_shown_in_list
# 6  2042647  3341664      7115                6  object_shown_in_list
# 7  2042654  3341664      7115                6  object_shown_in_list
#
#    eventValue_x    position                 date     id_y eventType_y  \
# 2             1  recomended  2020-01-15 23:08:36  4402430    pageview
# 4             1  recomended  2020-01-15 23:14:36  4402306    pageview
# 5             1  recomended  2020-01-15 23:14:57  4402306    pageview
# 6             1  recomended  2020-01-15 23:15:50  4402306    pageview
# 7             1  recomended  2020-01-15 23:17:55  4402306    pageview
#
#    eventValue_y         lastModified               dateX       lastModifiedX  \
# 2             1  2020-01-15 23:09:12 2020-01-15 23:08:36 2020-01-15 23:09:12
# 4             2  2020-01-15 23:21:25 2020-01-15 23:14:36 2020-01-15 23:21:25
# 5             2  2020-01-15 23:21:25 2020-01-15 23:14:57 2020-01-15 23:21:25
# 6             2  2020-01-15 23:21:25 2020-01-15 23:15:50 2020-01-15 23:21:25
# 7             2  2020-01-15 23:21:25 2020-01-15 23:17:55 2020-01-15 23:21:25
#
#    dtDiff
# 2      36
# 4     409
# 5     388
# 6     335
# 7     210

# %%
(merged.shape, mergedRestr.shape)
# Out:
# ((25512, 15), (8594, 15))

# %%
mergedRestr["recVariant"] = mergedRestr.userID % 6
mergedRestr = mergedRestr[["recVariant","date","lastModified"]]
mergedRestr.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#    recVariant                 date         lastModified
# 2           0  2020-01-15 23:08:36  2020-01-15 23:09:12
# 4           0  2020-01-15 23:14:36  2020-01-15 23:21:25
# 5           0  2020-01-15 23:14:57  2020-01-15 23:21:25
# 6           0  2020-01-15 23:15:50  2020-01-15 23:21:25
# 7           0  2020-01-15 23:17:55  2020-01-15 23:21:25

# %%
dfGroup = mergedRestr.groupby(by=["recVariant"])
dfSum = dfGroup.count()
dfSum
# Out:
#             date  lastModified
# recVariant
# 0           1695          1695
# 1           1022          1022
# 2           2043          2043
# 3           1481          1481
# 4           1299          1299
# 5           1054          1054

# %%
dfSum.sum()
# Out:
# date            8594
# lastModified    8594
# dtype: int64

# %%
resOO["visits"] = dfSum.date
dfSum.date/resSO.cnt
# Out:
# recVariant
# 0    0.077228
# 1    0.060438
# 2    0.102969
# 3    0.086644
# 4    0.066316
# 5    0.056418
# dtype: float64

# %%
algVariants = ["Best old, CTR",
            "Cosine CB",
            "Word2vec",
            "Best Current, CTR",
            "Best Old, VRR",
            "Best Current, VRR"
            ]

# %%
resOO["algNames"] = algVariants
resOO = resOO.set_index("algNames")
resOO
# Out:
#                    cnt  users  clicks  shown  user_conversion  visits
# algNames
# Best old, CTR      152    664     152  21948         0.126506    1695
# Cosine CB          109    628     109  16910         0.108280    1022
# Word2vec           152    668     152  19841         0.128743    2043
# Best Current, CTR  109    637     109  17093         0.098901    1481
# Best Old, VRR      100    655     100  19588         0.102290    1299
# Best Current, VRR   91    646      91  18682         0.086687    1054

# %%
from scipy.stats import fisher_exact

fisher_exact(resOO.iloc[[3,2],[2,1]])
# Out:
# (0.7520036354622821, 0.04160754127185018)

# %%
resOO.iloc[[0,2],[2,3]]
# Out:
#                clicks  shown
# algNames
# Best old, CTR     152  21948
# Word2vec          152  19841

# %%
resOO["ctr"] = resOO["clicks"]/resOO["shown"]
resOO["vrr"] = resOO["visits"]/resOO["shown"]
resOO["ctr_u"] = resOO["clicks"]/resOO["users"]
resOO["vrr_u"] = resOO["visits"]/resOO["users"]
resOO["shr"] = resOO["shown"]/resOO["users"]
resOO
# Out:
#                    cnt  users  clicks  shown  user_conversion  visits  \
# algNames
# Best old, CTR      152    664     152  21948         0.126506    1695
# Cosine CB          109    628     109  16910         0.108280    1022
# Word2vec           152    668     152  19841         0.128743    2043
# Best Current, CTR  109    637     109  17093         0.098901    1481
# Best Old, VRR      100    655     100  19588         0.102290    1299
# Best Current, VRR   91    646      91  18682         0.086687    1054
#
#                         ctr       vrr     ctr_u     vrr_u        shr
# algNames
# Best old, CTR      0.006925  0.077228  0.228916  2.552711  33.054217
# Cosine CB          0.006446  0.060438  0.173567  1.627389  26.926752
# Word2vec           0.007661  0.102969  0.227545  3.058383  29.702096
# Best Current, CTR  0.006377  0.086644  0.171115  2.324961  26.833595
# Best Old, VRR      0.005105  0.066316  0.152672  1.983206  29.905344
# Best Current, VRR  0.004871  0.056418  0.140867  1.631579  28.919505
